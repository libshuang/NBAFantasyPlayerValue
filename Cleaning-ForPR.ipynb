# %%
#assume that injuries dont count in this projection count
#not going to incorporate teams too
import seaborn as sns
import scipy as sc

# %% [markdown]
# ### Import df

# %%
df = pd.read_csv('stats2020.csv')
df
# Out:
#       Rk                    Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 0      1              Steven Adams   C   26  OKC  58  58  27.0  4.5   7.6
# 1      2               Bam Adebayo  PF   22  MIA  65  65  34.4  6.3  11.1
# 2      3         LaMarcus Aldridge   C   34  SAS  53  53  33.1  7.4  15.0
# 3      4  Nickeil Alexander-Walker  SG   21  NOP  41   0  12.2  1.9   5.5
# 4      5             Grayson Allen  SG   24  MEM  30   0  16.6  2.6   5.9
# ..   ...                       ...  ..  ...  ...  ..  ..   ...  ...   ...
# 619  510            Thaddeus Young  PF   31  CHI  64  16  24.9  4.2   9.4
# 620  511                Trae Young  PG   21  ATL  60  60  35.3  9.1  20.8
# 621  512               Cody Zeller   C   27  CHO  58  39  23.1  4.3   8.3
# 622  513                Ante Žižić   C   23  CLE  22   0  10.0  1.9   3.3
# 623  514               Ivica Zubac   C   22  LAC  64  62  18.1  3.2   5.3
#
#      ...    FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df2 = pd.read_csv('stats2020.csv')

# %%
df.dropna(subset = ['2P%', 'FG%', 'eFG%'], inplace = True)
df.fillna(value = 0, inplace = True)
df2.dropna(subset = ['2P%', 'FG%', 'eFG%'], inplace = True)
df2.fillna(value = 0, inplace = True)

# %%
df.reset_index(drop = True, inplace = True)
df2.reset_index(drop = True, inplace = True)

# %%
df[df.columns[6]] = sc.stats.zscore(df[df.columns[6]])

# %%
for col in range(5,29):
    df[df.columns[col]] = sc.stats.zscore(df[df.columns[col]])

# %%
final_df = df2.merge(df, left_index = True, right_index = True)

# %%
final_df.to_csv('z_scores_2020.csv', index = False)

# %% [markdown]
# ### Visualisations

# %% [markdown]
# ### Missing Data

# %%
def find_missing(data):
    # number of missing values
    count_missing = data.isnull().sum().values
    # total records
    total = data.shape[0]
    # percentage of missing
    ratio_missing = count_missing/total
    # return a dataframe to show: feature name, # of missing and % of missing
    return pd.DataFrame(data={'missing_count':count_missing, 'missing_ratio':ratio_missing}, index=data.columns.values)

# %%
df.dropna(subset = ['2P%', 'FG%', 'eFG%'], inplace = True)
df.fillna(value = 0, inplace = True)
